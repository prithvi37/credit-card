# %% [markdown]
# # ASSIGNMENT 1: Emerging AI Technologies
#
# Group 4
#
#  Rushil Ketanbhai Bhavsar
#  Ayush Bharatkumar Borad
#  Jaykumar Vinubhai Dayani
#  Prithvi Naresh Kaklotar
#  Devika Jitesh Patel
#  Akshat Tyagi

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# Credit Cards are integral part of our lifes. As per a statistics there are 1.1 billion credit cards only in the US as of 2022. Although, this a good sign but at the same time when spending money becomes easy,frauds increase!
# The statistics in the image below say that global credit card frauds in 2018 accounted for a total loss of 27.85 billion US dollars and the loss predicted for 2023 will be 35.67 billion US dollars.As per another research, false declines made the client’s loss around $9 billion per year.
#
# Hence,accurate,scalableand cost efficient detection of a Fraud Transaction on Credit Cards becomes an area of immediate research for financial institutions and Other Organizations.
#
# ![image.png](attachment:image.png)
#
# At an initial phase,in this work, we will use PyTorch Framework for Credit Card Fraud Detection and later explore scalability options

# %% [markdown]
# Image Reference
#
# Tarver J.(October 5,2020),7 Eye-opening Credit Card Fraud Statistics,from https://fitsmallbusiness.com/credit-card-fraud-statistics/

# %% [markdown]
# # Introduction:

# %% [markdown]
# In the last decade, there has been an exponential growth of the internet which increased  the use of services such as e-commerce,tap and pay systems, online bills payment systems etc. Due to this, fraudsters have also incresed activities to attack transactions made with credit cards.There is some extent of security by using encryption and tokenization but sometimes they do not fully protect credit card transactions against Fraud. Machine Learning techniques are used to develop computational methodlogies, which can detect non-legitimate transactions based on amount and time of those transactions.Fraud Detection, for credit cards, is the method of distinguishing. between  fraudulent and genuine transactions.
#  Credit Card Fraud Detection is a challenging task because of constantly changing nature and patterns of Fraudulent transactions. Furthermore,the another challenge while dealing with fraud detection is that real data is hardly ever available for exploration due to confidentiality issue.In this work, we will use PyTorch Framework for Credit Card Fraud Detection.

# %% [markdown]
# # Literature Review:

# %% [markdown]
# # Research Paper 1: Using neural network for credit card fraud detection

# %% [markdown]
#  In this paper, the researcher has focused on balancing the dataset since the main characteristics of credit card traffic is the imbalanced dataset and confidentiality issues. So, the researcher has balanced the data and then performed Artificial Neural Network.
#
#  ![image.png](attachment:image.png)
#
# They have used random undersampling to balance the data
#
# ![image-2.png](attachment:image-2.png)
#
# The  network  is  trained  with  Scaled  Conjugate  Gradient  (SCG)  backpropagation  algorithm.Scaled Conjugate Gradient (SCG) is an optimization algorithm used for training artificial neural networks. It is a variant of the Conjugate Gradient method and is designed to handle the large scale and high-dimensional problems that arise in neural network training. It is faster and more efficient than other traditional backpropagation algorithms and can handle large datasets and multiple hidden layers. The SCG algorithm updates the network weights and biases based on the gradient of the error function with respect to the weights, and uses the conjugate gradient method to determine the direction of the weight updates.
#
# The best result was given by the follwing defined model:
#
# ![image-3.png](attachment:image-3.png)
#
# The model gives good results but the issue here is still that  false  negative  (predict  that a transaction is not fraudulent  when  it  is)  results  are  only 1.3% and false positive (predict that a transaction is fraudulent when it actually is not) results are 4.4%.
#
# This could be huge loss to the bank or the merchant.

# %% [markdown]
# # Research Paper 2:  A Combination of K-Nearest Neighbor and Deep Neural Networks for Credit Card Fraud Detection

# %% [markdown]
# In this paper, the researcher was focused on establishing a comparison between KNN and Deep Neural Network.
# First step they performed was under sampling.
#
# Applied KNN with k=5(Best result)
# ![image.png](attachment:image.png)
#
# The DNN model that gave the best response with 100 iterations and 32 batch size was follows:
# ![image-2.png](attachment:image-2.png)
#
# The Paper Concluded that DNN out performed KNN

# %% [markdown]
# # Research Paper 3: A novel approach to increase scalability while training machine learning algorithms using Bfloat – 16 in credit card fraud detection.

# %% [markdown]
# In this paper the researcher pointed out an interesting observation. According to them, till now all the algorithms that we used focused only on the accuracy of determining whether a transaction is fraud or not. But when it comes to practical scenario from a business point of view, two important metrics come into play, that is time and cost.The goal of the researcher was to prove that using fewer bits for training a machine learning algorithm will result in a more scalable system i.e. that it will reduce the time and will also be less costly to implement.
#
# Machine learning needs large sets of data to train a model and training a model can take an extended time. A bank fraud detection system has real-time frauds appearing and this requires for a more efficient system. Also, a model can be so big that it cannot fit into the working memory of the training device.
#
# The currently available machine learning algorithm for scalability focuses primarily on distributed computing such as using multicore processors, GPUs or HPCC which is quite costly.
#
# The proposed idea in this research paper is as follows:
#
# The idea is to implement low precision training method. Generally, machine learning frameworks, by
# default, use 32-bit floating point precision for inference and training the models. There is evidence that we
# can use to lower numerical precision (like 16-bit for training, and 8-bit for inference) at the cost of minimal
# accuracy.
# We are using float16 bit which will use 16-bits to represent the floating-point number. It is also known as
# half-precision float. The first is used for sign bit, the next 5-bits are used for exponent and the last 10-bits
# for fraction/mantissa. It is easily available to use in numpy library of python.
# Reducing the precision will right away lead to reduced memory footprint, better bandwidth utilization,
# improved caching, throughput will be doubled, and sped up model performance (hardware can perform
# more operations per second on low precision operands).
#
# ![image.png](attachment:image.png)
#
# As shown above, the CPU execution time taken with float16 is almost 55% less than without the float16 bits.
#
# ![image-2.png](attachment:image-2.png)
#
# As clearly depicted in the above graph, we can deduce that by using float16 bits we can achieve machine
# learning scalability by reducing the CPU execution time which will result in faster processing and utilization
# of less resources.
#
# The Researcher Concluded as follows:
#
# The thesis aimed to implement a machine learning based scalability for banks credit card fraud detection
# system. We can conclude based on the results and comparison depicted that execution time was reduced by
# 50%-60% after we implemented float16 bits on the data. The results also indicate that the accuracy was
# reduced after implementing float16 bits, but it was only reduced by 0.0002% for unbalanced data and
# balanced data.

# %% [markdown]
# # Solution for this problem:(Approach which we used)

# %% [markdown]
#  # Design Neural Network for credit card fraud detection by using PyTorch
#
#  Here we are building a 5-layer deep neural network using sequential model.
#  For first hidden layer,'input_dim' is the number of input variables.'units' is the number of neurons in each layer.In this architecture, we used Rectified Linear Unit(ReLU) as an activation function for the hidden layers. When model Architecture built, we will train the model. Further, we used 'binary_crossentropy' as the loss function and 'Adam' to update network weights.'Adam' is a popular algorithm to achieve good results faster in the deep learning field.
#  An epoche represents one time that the entire training set is fed through the network. and batch defines the number of samples to iterate through before updating the internal model parameters. At the end of the batch, the predictions are compared to the expected output, and error is calculated. Using this error, the optimizer improves the model by moving down the error gradient.The model is found with 98% accuracy. At the end of code sample of fraud detection classifier, classification report and confusion matrix displays result of this model. In classification report, Precision shows that the model  is 95%  actually doing what was predicted and recall also shows 73% which means the model predicted this outcome correctly for 73%. and its displays f1-score and support 0.82 and 142 respectively. From this output, it proves that model provides good accuracy results.

# %% [markdown]
# III.Tools used to build a credit card fraud detection Classifier:
#
# 1. PyTorch: A popular deep learning framework for building and training neural networks.
# 2. Pandas: Pandas is a library for data analysis.It can be used to preprocess thecredit card transaction data.
# 3. Numpy: It is a library for numerical computing in Python.
# 4. Matplotlib: A data visualization library that can be used to plot graphs and visualize patterns in the data.
# 5. Scikit-learn: This library can be used for splitting the data into training and testing sets and for evaluating the performance of the classifier.
# 6. Seaborn: A data visualization library based on Matplotlib that can be used to create more attractive and informative plots and charts.

# %% [markdown]
# # How Reading the research papers influenced our solution?

# %% [markdown]
# The first research paper was focussed on balancing the data. So, from there we implemented balancing using Over Sampling.
# The second research paper gave us a comparison of KNN and DNN, with conclusion that DNN performed better.
# So, we tried to combine both the methods and implement a neural network with Relu activation function, balancing the data and a neural network with 5 layers-10 iterations and 128 batch size.
# This resulted in a high accuracy

# %% [markdown]
# # DATA COLLECTION
#
# For the Purpose of credit card fraud detection, credit card transactions dataset from Kaggle was used.

# %%
import torch
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import sum
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import TensorDataset, DataLoader
from tqdm import tqdm
df=pd.read_csv("creditcard.csv")
plt.rcParams["figure.figsize"] = (14,7)
from sklearn import metrics
from datetime import datetime

# %% [markdown]
# # DATA INSPECTION

# %%
df.head(86)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ..   ...       ...       ...       ...       ...       ...       ...
# 81  52.0  1.147369  0.059035  0.263632  1.211023 -0.044096  0.301067
# 82  52.0 -3.005237  2.600138  1.483691 -2.418473  0.306326 -0.824575
# 83  53.0 -1.198968 -1.474100  1.840326 -4.515824  0.327567 -0.174469
# 84  54.0  1.202398  0.321711  0.281211  0.643689 -0.148669 -0.589739
# 85  55.0 -4.575093 -4.429184  3.402585  0.903915  3.002224 -0.491078
#
#           V7        V8        V9  ...       V21       V22       V23       V24  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# We can clearly see that we don't have any null values in the data.

# %%
print(f"Number of data points: {df.size}")
print(f"Number of Fradulant Transactions: {df['Class'].value_counts()[1]}")
print(f"Number of non-fradulant Transactions: {df['Class'].value_counts()[0]}\n\n")
# Out:
# Number of data points: 8829017
# Number of Fradulant Transactions: 492
# Number of non-fradulant Transactions: 284315

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
Fraud = df[df["Class"] == 1]
Normal = df[df["Class"] == 0]
print(Fraud.shape)
print(Normal.shape)
# Out:
# (492, 31)
# (284315, 31)

# %%
df[["Amount", "Time"]].describe()
# Out:
#               Amount           Time
# count  284807.000000  284807.000000
# mean       88.349619   94813.859575
# std       250.120109   47488.145955
# min         0.000000       0.000000
# 25%         5.600000   54201.500000
# 50%        22.000000   84692.000000
# 75%        77.165000  139320.500000
# max     25691.160000  172792.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.hist(df["Class"], bins=2)
# Out:
# (array([284315.,    492.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#randomly selecting 442 random non-fraudulent transactin, but normalizing data before undersampling
fraud = df[df['Class'] == 1]
non_fraud = df[df['Class'] == 0].sample(len(fraud) * 5)
non_fraud.reset_index(drop=True, inplace=True)
fraud.reset_index(drop=True, inplace=True)
new_df = pd.concat([non_fraud, fraud]).sample(frac=1).reset_index(drop=True)
new_df.describe()
# Out:
#                 Time           V1           V2           V3           V4  \
# count    2952.000000  2952.000000  2952.000000  2952.000000  2952.000000
# mean    93062.078930    -0.775830     0.616288    -1.178144     0.800328
# std     47710.454481     3.729671     2.667271     4.136041     2.412822
# min       140.000000   -32.353040   -30.104882   -31.103685    -4.629003
# 25%     51793.250000    -1.259525    -0.464903    -1.663704    -0.657483
# 50%     85285.000000    -0.272265     0.243365    -0.151624     0.281742
# 75%    137909.750000     1.240670     1.126377     0.907948     1.338908
# max    172696.000000     2.380213    22.057729     3.621715    12.114672
#
#                 V5           V6           V7           V8           V9  ...  \
# count  2952.000000  2952.000000  2952.000000  2952.000000  2952.000000  ...
# mean     -0.502483    -0.221811    -0.923205     0.091706    -0.419924  ...
# std       2.751793     1.535778     3.777203     3.238588     1.710385  ...
# ...

# %% [markdown]
# # Understanding the Correlation Among the features in the Data

# %%
corrmat = new_df.corr()
corrmat_orig = df.corr()
f, ax = plt.subplots(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.title('Correlation matrix of sub-sampled data')
sns.heatmap(corrmat, vmax=1, square=True)
plt.subplot(1, 2, 2)
plt.title('Correlation matrix of original data')
sns.heatmap(corrmat_orig, vmax=1, square=True)
# Out:
# <AxesSubplot:title={'center':'Correlation matrix of original data'}>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df["Hour"] = df["Time"].apply(datetime.fromtimestamp).dt.hour
fig, ax = plt.subplots(2, figsize=(10,7))
for a in ax:
    a.set_xticks(range(24))
df.loc[df["Class"] == 0]["Hour"].hist(bins=np.arange(24)-0.5, ax=ax[0], grid=False)
df.loc[df["Class"] == 1]["Hour"].hist(bins=np.arange(24)-0.5, ax=ax[1], grid=False)
ax[0].title.set_text("Legitimate Transactions")
ax[1].title.set_text("Fraudulent Transactions")
plt.subplots_adjust(hspace=0.3)

# %%
ax = df.drop("Class", axis=1).hist(figsize=(10,12),bins=100)
# We hide the axes' labels to make the plot neater and more compact
for axis in ax.flatten():
    axis.set_xticklabels([])
    axis.set_yticklabels([])

# %%
df["Amount"][df["Class"] == 1].hist(figsize=(10,10))
plt.show()

# %%
# fraud
df["Amount"][df["Class"] == 1].plot(figsize = (40,10))
plt.show()

# %%
df["Time"][df["Class"] == 1].hist(figsize=(10,10))
plt.show()

# %%
sns.distplot(df.loc[df['Class'] == 0]["Time"], hist=True)
sns.distplot(df.loc[df['Class'] == 1]["Time"], hist=True)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Density'>

# %%
sns.scatterplot(x="Amount", y="V1",hue="Class",data=df)
# Out:
# <AxesSubplot:xlabel='Amount', ylabel='V1'>

# %%
df.hist(figsize=(20,20));

# %%
print('\n\033[1m  Fraudulent Transaction Distribution by amount \033[0m')
print("-"*50)
print(df[(df['Class'] == 1)]['Amount'].value_counts().head())
# Out:
#   Fraudulent Transaction Distribution by amount
# --------------------------------------------------
# 1.00     113
# 0.00      27
# 99.99     27
# 0.76      17
# 0.77      10
# Name: Amount, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Data Splitting

# %%
# split data into training and testing
X = df.drop("Class", axis=1)
y = df["Class"]

# scale the values of x (better training)
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# split data to train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, stratify=y) # stratify keeps class balance

# %%
# create tensor datasets from df
X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.FloatTensor(y_train.values)
y_test = torch.FloatTensor(y_test.values)
train_ds = TensorDataset(X_train, y_train)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cpu

# %%
# create dataloaders
batch_size = 128
train_dl = DataLoader(train_ds, batch_size=batch_size)

# %% [markdown]
# # Model Selection and Training

# %%
# Network Architecture
class FraudNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers=4):
        super().__init__()
        self.input = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU()
        )
        # make the number of hidden dim layers configurable
        self.layers = nn.ModuleList()
        for i in range(num_layers):
            self.layers.append(nn.Linear(hidden_dim, hidden_dim))
            self.layers.append(nn.ReLU())
        
        # final layer
        self.fc = nn.Linear(hidden_dim, 2)
        
    def forward(self, x):
        out = self.input(x)
        for layer in self.layers:
            out = layer(out)
        return self.fc(out)

# %%
# training function
def train_model(model, epochs, loss_fn, optimizer):
    model.train()   
    for epoch in range(epochs):
        with tqdm(train_dl, unit="batch") as tepoch:
            for data, target in tepoch:
                data, target = data.to(device), target.to(device)
                tepoch.set_description(f"Epoch {epoch}")
                optimizer.zero_grad()
                preds = model(data)
                loss = loss_fn(preds, target.long())
                loss.backward()
                optimizer.step()
                tepoch.set_postfix(loss=loss.item())

# %%
# !pip install torch-summary
# Out:
# ...
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)

# %%
from torchsummary import summary
inp_size = X_train.shape[1]
model = FraudNet(inp_size, inp_size).to(device)
loss = nn.CrossEntropyLoss()
optim = torch.optim.Adam(model.parameters(),  lr = 1e-4)

# summarize the model layers
summary(model, (inp_size, inp_size))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─Sequential: 1-1                        [-1, 31, 31]              --
# |    └─Linear: 2-1                       [-1, 31, 31]              992
# |    └─ReLU: 2-2                         [-1, 31, 31]              --
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-3                       [-1, 31, 31]              992
# |    └─ReLU: 2-4                         [-1, 31, 31]              --
# |    └─Linear: 2-5                       [-1, 31, 31]              992
# |    └─ReLU: 2-6                         [-1, 31, 31]              --
# |    └─Linear: 2-7                       [-1, 31, 31]              992
# |    └─ReLU: 2-8                         [-1, 31, 31]              --
# |    └─Linear: 2-9                       [-1, 31, 31]              992
# |    └─ReLU: 2-10                        [-1, 31, 31]              --
# ...

# %%
epochs = 10
train_model(model, epochs, loss, optim)
# Out:
# ...
# Epoch 9: 100%|███████████████████████████████████████████████████| 1552/1552 [00:08<00:00, 177.21batch/s, loss=0.00018]

# %% [markdown]
# # Model Evaluation

# %%
model.eval()
preds = model(X_test.to("cpu")).argmax(dim=1)
print(classification_report(y_test, preds.cpu()))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     84976
#          1.0       0.82      0.77      0.79       142
#
#     accuracy                           1.00     85118
#    macro avg       0.91      0.88      0.90     85118
# weighted avg       1.00      1.00      1.00     85118

# %%
class_def = {0 : "Not Fraudulent", 1 : "Fraudulent"}
cm_df = pd.DataFrame(confusion_matrix(y_test, preds.cpu())).rename(columns=class_def, index=class_def)
cm_df = cm_df / sum(cm_df)
sns.heatmap(cm_df, annot=True, fmt='0.2%', cmap="YlGnBu").set(title="Confusion Matrix", xlabel="Predicted Label", ylabel="True Label")
plt.show()

# %% [markdown]
#  Model training losses seem to converge nicely, our model provided in predicting the frudulent cases.
# Fraudulent vs non fraudulent reconstruction error losses.
#
# After comparing graphs of both fraud and nonfraudlent cases we can see that where non fraudulent cases as expected show minimum reconstruction losses, quite a few fraudulent cases do show significant reconstruction error losses, which indicates that model is indeed able to detect fraudulent cases.

# %% [markdown]
# Conclusion:we can see that our model seems to catch a lot of the fraudulent cases. But the number of normal transactions classified as frauds is really high.
#  we Implemented a Neural Network using PyTorch Framework that can reconstruct what non fraudulent transactions looks like. Network learn to recognise the non fraudulent transactions by learning some patterns present in the those transactions. so, it helps to detect  credit card fraud activities.
# Our model provides good accuracy results for this dataset.

# %% [markdown]
# We compute accuracy,recall, precision value and f1 score at the end of the model.

# %% [markdown]
# # Reference:
#
# Rzayeva D., Malekzadeh S. (2020, February 2). A Combination of K-Nearest Neighbor and Deep Neural Networks for Credit Card Fraud Detection, from https://arxiv.org/ftp/arxiv/papers/2205/2205.15300.pdf
#
# Yousuf B.,Sulaiman R. B., Nipun M. S., A novel approach to increase scalability while training
# machine learning algorithms using Bfloat – 16 in credit card fraud detection., from https://arxiv.org/ftp/arxiv/papers/2206/2206.12415.pdf
#
#
# Georgieva S., Markova M., Pavlov V., (2019, October 2). Using neural network for credit card frauddetection, from https://www.researchgate.net/publication/336238926_Using_neural_network_for_credit_card_fraud_detection
#
# Code Reference: https://www.kaggle.com/code/dktalaicha/credit-card-fraud-detection-using-smote-adasyn

# %% [markdown]
# # End
